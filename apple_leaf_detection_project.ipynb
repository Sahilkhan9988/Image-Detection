# %% [markdown]
# <a href="https://colab.research.google.com/github/Sahilkhan9988/Image-Detection/blob/main/apple_leaf_detection_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 723.1/723.1 kB 4.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 21.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 49.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 41.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 1.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 2.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 2.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 947.6 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 867.5 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 1.2 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %%
# !touch data.yaml

# %%
model = YOLO("yolov8m.pt")
# Out:
# ...
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 205MB/s]

# %%
results = model.train(data="/content/data.yaml",epochs=30)
# Out:
# Ultralytics YOLOv8.1.34 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
refer = YOLO("/content/runs/detect/train2/weights/best.pt")

# %%
refer.predict("/content/drive/MyDrive/Okul Meyve 2.v2i.yolov8/test/images",save=True,save_txt=True)
# Out:
# image 1/89 /content/drive/MyDrive/Okul Meyve 2.v2i.yolov8/test/images/Screen-Shot-2018-06-12-at-11-19-47-PM_png_jpg.rf.77e1690bc256fad6d01182a2589e8505.jpg: 640x640 1 sagliksiz, 37.4ms
# image 2/89 /content/drive/MyDrive/Okul Meyve 2.v2i.yolov8/test/images/Screen-Shot-2018-06-12-at-11-21-17-PM_png_jpg.rf.9b0342392d46b948f5c14c81e19f06e5.jpg: 640x640 1 sagliksiz, 37.2ms
# image 3/89 /content/drive/MyDrive/Okul Meyve 2.v2i.yolov8/test/images/Screen-Shot-2018-06-12-at-11-24-51-PM_png_jpg.rf.609a86e4dc4fbe1b9404e3a72a1eadd4.jpg: 640x640 1 sagliksiz, 37.2ms
# image 4/89 /content/drive/MyDrive/Okul Meyve 2.v2i.yolov8/test/images/Screen-Shot-2018-06-12-at-11-25-11-PM_png_jpg.rf.c8d9708934a7a4c91120825ad62a93d2.jpg: 640x640 1 sagliksiz, 37.3ms
# image 5/89 /content/drive/MyDrive/Okul Meyve 2.v2i.yolov8/test/images/Screen-Shot-2018-06-12-at-11-25-38-PM_png_jpg.rf.0a50c466e154ec77569f71b496e8955a.jpg: 640x640 1 sagliksiz, 27.5ms
# ...
